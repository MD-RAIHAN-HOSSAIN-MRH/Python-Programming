# %%
# Algorithms

# Searching Algorithms

# Sequential Search
def Sequential_Search(target):
  arr = [10,20,30,40,50]
  flag = False
  for i in arr:
    if(i == target):
      flag = True
  print(flag)


Sequential_Search(45)
# Out:
# False

# %%
# Binary Search
