# %%
# This is a comment
# We will write the code here!

print("Hello World!")
print("Hello World Again!")
print("Hello World Again and Again!")
print("Hello World! Again and Again and Again!")

# TERMINAL
# Out:
# Hello World!
# Hello World Again!
# Hello World Again and Again!
# Hello World! Again and Again and Again!

# %%
# printing multiple lines
print("This is a line! \nThis is another line! \nThis is the third line!")
print("\n\n\n\nThis is a new line")
# Out:
# This is a line!
# This is another line!
# This is the third line!
#
#
#
#
# This is a new line

# %%
# This is string data type
print(type("Creative IT")) # This is a string data type
print(type(2024)) # This is an integer data type
print(type(2024.1)) # This is a floating point number # Decimal Value
print(type(False))   # This is a boolean data type --> True/False
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Variables
# Containers

# x is the name of a variable!
x = "Creative IT "
print(x)
print(type(x))

# y is the name of a variable!
y = 2024
print(y)
print(type(y))

# z is the name of a variable!
z = False
print(z)
print(type(z))
# Out:
# Creative IT
# 2024
# False
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
# artihmetic operations
print(5 + 5)
print(5 - 5)
print(5 * 5)
print(5 / 5)
# Out:
# 10
# 0
# 25
# 1.0

# %%
# power operation
# Exponent operator
print(2 ** 8)

# modular operation
# % --> This is the modular operator!
print(10  % 3)
# Out:
# 256
# 1

# %%
# vartiable  --> x --> 100
# vartiable  --> y --> 6
# variable --> z --> 100/6 --> remainder --> print!
x = 100
y = 6
z = x % y
print("This is the answer: ")
print(z)
# Out:
# This is the answer:
# 4

# %%
# arithmeric opeation using variables

month = 30
year = 12
days_in_one_year = month * year
print(days_in_one_year)
# Out:
# 372

# %%
# the total number of seconds in a day
hour = 24
minute = 60
second = 60

total_seconds_one_day  = hour * minute * second
print(total_seconds_one_day)

# Finding the numer of seconds in a year
print(total_seconds_one_day * 365)
# Out:
# 86400
# 31536000

# %%
# Printing Patterns
# Alpha Alpha Alpha
# Alpha Alpha Alpha
# Alpha Alpha Alpha

# concatenation
print('Alpha ' + 'Alpha ' + 'Alpha \n' + 'Alpha ' + 'Alpha ' + 'Alpha \n' + 'Alpha ' + 'Alpha ' + 'Alpha ')
# Out:
# Alpha Alpha Alpha
# Alpha Alpha Alpha
# Alpha Alpha Alpha

# %%
symbol = 'Alpha'
print(symbol + " " +  symbol + " " + symbol + " " + "\n" + symbol + " " +  symbol + " " + symbol +  "\n" + symbol + " " +  symbol + " " + symbol)
# Out:
# Gamma Gamma Gamma
# Gamma Gamma Gamma
# Gamma Gamma Gamma

# %%
symbol = 'Beta'
print(symbol + " " +  symbol + " " + symbol + " " + "\n" + symbol + " " +  symbol + " " + symbol +  "\n" + symbol + " " +  symbol + " " + symbol)
# Out:
# Beta Beta Beta
# Beta Beta Beta
# Beta Beta Beta

# %%
symbol = 'Gamma'
print(symbol + " " +  symbol + " " + symbol + " " + "\n" + symbol + " " +  symbol + " " + symbol +  "\n" + symbol + " " +  symbol + " " + symbol)
# Out:
# Gamma Gamma Gamma
# Gamma Gamma Gamma
# Gamma Gamma Gamma

# %%
symbol = '***'
print(symbol + " " +  symbol + " " + symbol + " " + "\n" + symbol + " " +  symbol + " " + symbol +  "\n" + symbol + " " +  symbol + " " + symbol)
# Out:
# *** *** ***
# *** *** ***
# *** *** ***

# %%
# Concatenation
x = " Creative"
y = "IT"
z = "Institute"
print(x + " " + y + " " + z)
#Creative IT Institute
print("Welcome to " + x + " " + y + " " + z + "!")
# Out:
#  Creative IT Institute
# Welcome to  Creative IT Institute!

# %%
name = "Creative IT"
print("Welcome to " + name)
# format string
print(f'Welcome to {name} !')
# Out:
# Welcome to Creative IT
# Welcome to Creative IT !

# %%
# User will give us name
# We will greet the user
#name = "Alex"
name = input("Please enter your full name: ")
print(f'Welcome to the system {name} !')
# Out:
# Please enter your full name: Creative
# Welcome to the system Creative !

# %%
# take 2 values from the user --> integer
# and then add them and show the result
# Typecasting
x = int(input("Give me a number: "))
y = int(input(" Give me another number: "))
z =x + y
print(z)
# Out:
# Give me a number: 5
#  Give me another number: 5
# 10

# %%
# take 2 values from the user --> float
# and then add them and show the result
# Typecasting
x = float(input("Give me a number: "))
y = float(input(" Give me another number: "))
z =x + y
print(z)
# Out:
# Give me a number: 5
#  Give me another number: 6
# 11.0

# %%
status = bool(input("Give me the voting status(True/False): "))
print(type(status))
print(status)
# Out:
# Give me the voting status(True/False):
# <class 'bool'>
# False

# %%
# decision making
# If there is rain --> stay at home
# else --> go outside!

# rain = bool(input("Give me the status of the rain:"))
rain = False
# conditional
if(rain == True):
  # indentation
  print("Stay at Home!")
else:
  print("Go Outside!")
# Out:
# Stay at Home!

# %%
# The exam_mark  will be taken from  the user
# If the exam_mark is >= 60, then print --> "You have passed"
# else --> "You have failed!"

exam_mark = int(input("Please give me the marks for the exam: "))
if (exam_mark >= 60):
  print("You have passed!")
else:
  print("You have failed!")
# Out:
# Please give me the marks for the exam: 565
# You have passed!
